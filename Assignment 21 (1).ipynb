# %% [markdown]
# ## Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# Matplotlib is a popular Python library for creating static, animated, and interactive visualizations. It is widely used by scientists, engineers, and data analysts to generate plots, charts, and illustrations for papers, presentations, and reports.
#
# Five plots that can be plotted using the Pyplot module of Matplotlib.
#
# A.Line plot
#
# B.Scatter plots
#
# C.Bar plots
#
# D.Histograms
#
# E.Pie chart

# %% [markdown]
# ## Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %% [raw]
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# It is a type of plot or mathematical diagram using Cartesian coordinates to display values for typically two variables for a set of data.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('this is title')
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Q3: Why is the subplot() function used? Draw four line plots using the subplot() function. Use the following data:

# %% [markdown]
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# The subplot() function in Matplotlib is used to create multiple plots on a single figure.

# %%
import numpy as np
import matplotlib.pyplot as plt

x1, y1 = np.array([0, 1, 2, 3, 4, 5]), np.array([0, 100, 200, 300, 400, 500])
x2, y2 = np.array([0, 1, 2, 3, 4, 5]), np.array([50, 20, 40, 20, 60, 70])
x3, y3 = np.array([0, 1, 2, 3, 4, 5]), np.array([10, 20, 30, 40, 50, 60])
x4, y4 = np.array([0, 1, 2, 3, 4, 5]), np.array([200, 350, 250, 550, 450, 150])

plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.plot(x1, y1, label='Line 1')
plt.title('Line 1')

plt.subplot(2, 2, 2)
plt.plot(x2, y2, label='Line 2')
plt.title('Line 2')

plt.subplot(2, 2, 3)
plt.plot(x3, y3, label='Line 3')
plt.title('Line 3')

plt.subplot(2, 2, 4)
plt.plot(x4, y4, label='Line 4')
plt.title('Line 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# A bar plot is a graphical representation of data where rectangular bars are used to represent the values of different categories. The length of each bar corresponds to the value it represents.
#
# Bar plots are used to compare and display the values of different categories, making it easy to observe patterns, trends, and variations in the data

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Bar plot
plt.figure(figsize=(8, 6))
plt.bar(company, profit, color='blue')
plt.xlabel('Company')
plt.ylabel('Profit (in millions)')
plt.title('Bar Plot of Company Profits')
plt.show()

# Horizontal bar plot
plt.figure(figsize=(8, 6))
plt.barh(company, profit, color='green')
plt.xlabel('Profit (in millions)')
plt.ylabel('Company')
plt.title('Horizontal Bar Plot of Company Profits')
plt.show()

# %% [markdown]
# ## Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %% [markdown]
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# A box plot (or box-and-whisker plot) is a statistical visualization that displays the distribution of a dataset and its central tendency. It is used to identify the spread, skewness, and potential outliers in the data.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = np.array([3000, 8000, 1000, 10000])

# Box plot
plt.figure(figsize=(8, 6))
plt.boxplot(data, vert=False)
plt.xlabel('Profit (in millions)')
plt.title('Box Plot of Company Profits')
plt.show()
